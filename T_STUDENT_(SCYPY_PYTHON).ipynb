# %% [markdown]
# <a href="https://colab.research.google.com/github/salvadorGoros/miner-a-de-datos/blob/main/T_STUDENT_(SCYPY_PYTHON).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1:
# Una empresa de tecnología afirma que el tiempo promedio que sus empleados tardan en resolver un ticket de soporte es de 45 minutos. Para verificar esta afirmación, se toma una muestra aleatoria de 25 empleados y se mide el tiempo (en minutos) que cada uno tarda en resolver un ticket. ¿El tiempo promedio de resolución de la muestra es significativamente diferente de 45 minutos?

# %%
import scipy.stats as stats

# Datos
datos = [42, 44, 46, 48, 43, 39, 45, 47, 41, 44, 46, 42, 40, 45, 43, 41, 44, 46, 42, 44, 40, 45, 43, 41, 44]
mu_teorica = 45

# Prueba t de una muestra
t_stat, p_valor = stats.ttest_1samp(datos, mu_teorica)

print(f"Estadístico t: {t_stat:.4f}")
print(f"P-valor: {p_valor:.4f}")
print("Resultado: Diferencia significativa" if p_valor < 0.05 else "No hay diferencia significativa")
# Out:
# Estadístico t: -3.4374
# P-valor: 0.0022
# Resultado: Diferencia significativa

# %% [markdown]
# Ejercicio 2:
# Un gimnasio quiere comparar la efectividad de dos programas de entrenamiento en la pérdida de peso. Para ello, selecciona 30 personas aleatoriamente y las divide en dos grupos:
# Grupo A: Entrenamiento tradicional
# Grupo B: Entrenamiento de alta intensidad
# Después de 3 meses, se mide la pérdida de peso (en kg) de cada persona. ¿Hay una diferencia significativa entre los dos programas?

# %%
import scipy.stats as stats

# Datos
grupo_a = [2, 3, 2.5, 4, 1.5, 3.5, 2, 3, 2.5, 4, 1, 2, 3, 2, 3]
grupo_b = [5, 4, 6, 5.5, 4.5, 5, 4, 6, 5, 4.5, 5, 6, 4, 5, 5.5]

# Prueba t para muestras independientes
t_stat, p_valor = stats.ttest_ind(grupo_a, grupo_b)

print(f"Estadístico t: {t_stat:.4f}")
print(f"P-valor: {p_valor:.4f}")
print("Resultado: Hay diferencia entre programas" if p_valor < 0.05 else "No hay diferencia significativa")
# Out:
# Estadístico t: -8.2902
# P-valor: 0.0000
# Resultado: Hay diferencia entre programas

# %% [markdown]
# Ejercicio 3:
# Un nutricionista quiere evaluar si una dieta especial reduce los niveles de colesterol en sus pacientes. Se seleccionan 20 personas y se miden sus niveles de colesterol antes y después de 2 meses de seguir la dieta. ¿Hubo una reducción significativa en los niveles de colesterol después del tratamiento?

# %%
import scipy.stats as stats

# Datos
antes = [220, 240, 210, 230, 250, 200, 215, 225, 235, 245, 210, 220, 230, 240, 250, 215, 225, 235, 245, 205]
despues = [200, 210, 195, 215, 220, 190, 205, 210, 220, 230, 200, 210, 215, 225, 230, 205, 210, 220, 230, 195]

# Prueba t pareada
t_stat, p_valor = stats.ttest_rel(antes, despues)

print(f"Estadístico t: {t_stat:.4f}")
print(f"P-valor: {p_valor:.4f}")
print("Resultado: Reducción significativa" if p_valor < 0.05 else "No hubo cambio significativo")
# Out:
# Estadístico t: 11.8972
# P-valor: 0.0000
# Resultado: Reducción significativa
